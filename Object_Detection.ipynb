# %% [markdown]
# <a href="https://colab.research.google.com/github/Suryakiran792/Bootcamp/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Object detection**

# %%
import cv2

# %%
img=cv2.imread('/content/download.jpg')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=290x174>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 48.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 841.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 59.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
#to import yolo from ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO('yolo11m.pt')
#11 is the version/m means medium
# Out:
# ...
# 100%|██████████| 38.8M/38.8M [00:00<00:00, 458MB/s]

# %%
result=model.predict('/content/download.jpg')
#to get the info in the result
# Out:
# image 1/1 /content/download.jpg: 384x640 6 persons, 1 car, 1 bus, 1 truck, 1 traffic light, 65.6ms
# Speed: 16.1ms preprocess, 65.6ms inference, 352.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
result.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e9c5472910e5> in <cell line: 0>()
# ----> 1 result.show()
#
# AttributeError: 'list' object has no attribute 'show'

# %%
result[0].show()
#to show the result
# Out:
# <PIL.Image.Image image mode=RGB size=290x174>

# %%
result1=model.predict('/content/download.jpg',save=True, conf=0.5)
#to save the result
#only consider values above 0.5
# Out:
# image 1/1 /content/download.jpg: 384x640 5 persons, 1 car, 1 bus, 1 truck, 24.3ms
# Speed: 3.7ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %%
# !git clone https://github.com/2nithing/yolo_beginner
# Out:
# Cloning into 'yolo_beginner'...
# remote: Enumerating objects: 3916, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 3916 (delta 0), reused 3 (delta 0), pack-reused 3910 (from 1)
# Receiving objects: 100% (3916/3916), 424.72 MiB | 16.75 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# Updating files: 100% (3817/3817), done.

# %%
model=YOLO('yolo11n.pt')
model.train(data='/content/yolo_beginner/drone_dataset/data.yaml',epochs=10,device=0)
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/yolo_beginner/runs/detect/train4/weights/best.pt')

# %%
result=model.predict('/content/multiple-drones-494x274.jpeg')
# Out:
# image 1/1 /content/multiple-drones-494x274.jpeg: 384x640 1 drone, 29.7ms
# Speed: 2.2ms preprocess, 29.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=494x274>

# %%
result=model.predict('/content/gettyimages-532142106-640x640.jpg')
# Out:
# image 1/1 /content/gettyimages-532142106-640x640.jpg: 384x640 2 drones, 10.5ms
# Speed: 3.8ms preprocess, 10.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=768x432>

# %%
result=model.predict('/content/yolo_beginner/drone.mp4',save=True,conf=0.5)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/300) /content/yolo_beginner/drone.mp4: 384x640 (no detections), 8.5ms
# video 1/1 (frame 2/300) /content/yolo_beginner/drone.mp4: 384x640 (no detections), 12.7ms
# video 1/1 (frame 3/300) /content/yolo_beginner/drone.mp4: 384x640 (no detections), 7.6ms
# video 1/1 (frame 4/300) /content/yolo_beginner/drone.mp4: 384x640 (no detections), 7.7ms
# ...

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
