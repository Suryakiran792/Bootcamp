# %% [markdown]
# <a href="https://colab.research.google.com/github/Suryakiran792/Bootcamp/blob/main/OpenCV_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
#to import the cv files

# %%
img=cv2.imread('/content/download (1).jpg')

# %%
cv2.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-4-3594ed6a38c9> in <cell line: 0>()
# ----> 1 cv2.imshow(img)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
#to display the image
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
img.shape
#to know the shape
# Out:
# (225, 225, 3)

# %%
img1=cv2.resize(img,(100,100))
cv2_imshow(img1)
#to resize and display the image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img2=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(img2)
#to convert the colour
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
img3=cv2.rectangle(img,(20,20),(100,100),(0,255,0),2)
cv2_imshow(img3)
#to create a rectangle in the image
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
img3=cv2.rectangle(img,(20,20),(100,100),(0,255,0),2)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
img3=cv2.rectangle(img.copy(),(100,100),(200,200),(0,0,255,),2)
cv2_imshow(img3)
#100,100 is postion
#200,200 is staring point and ending point
#0,0,255 is colour RGB
#2 is thickness of the rectangle
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
img3=cv2.rectangle(img.copy(),(100,100),(200,200),(0,0,255,),2)
cv2_imshow(img3)
cv2_imshow(img)
#to show original and an edited copy
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
img4=cv2.putText(img.copy(),"IGsK",(100,100),
                 cv2. FONT_HERSHEY_COMPLEX_SMALL,1,(255,0,0),2)
cv2_imshow(img4)
#to add text and its font to the image
#here 1 is text/font size and 2 is the thickness
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
img=cv2.imread('/content/istockphoto-1442556244-612x612.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>

# %%
img2=cv2.rectangle(img.copy(),(100,100),(200,200),(0,0,255,),2)
cv2_imshow(img2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>
# <PIL.Image.Image image mode=RGB size=612x408>

# %%
img2=cv2.rectangle(img.copy(),(100,100),(200,200),(0,0,255,),2)
img3=cv2.putText(img.copy(),"AMBILI",(100,100),
                 cv2. FONT_HERSHEY_COMPLEX_SMALL,1,(255,0,0),2)
cv2_imshow(img2)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>
# <PIL.Image.Image image mode=RGB size=612x408>

# %%
img=cv2.imread('/content/istockphoto-1442556244-612x612.jpg')
img1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img2=cv2.rectangle(img1.copy(),(200,10),(415,300),(0,0,255,),2)
img3=cv2.putText(img2.copy(),"AMBILI",(265,30),cv2. FONT_HERSHEY_COMPLEX_SMALL,1,(255,0,0),2)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=L size=612x408>

# %%
img=cv2.imread('/content/istockphoto-1442556244-612x612.jpg')
img2=cv2.rectangle(img.copy(),(200,40),(415,300),(0,0,255),2)
img3=cv2.putText(img2.copy(),"SESKY AMBILI",(225,30),cv2. FONT_HERSHEY_COMPLEX_SMALL,1,(255,0,0),2)
img3=cv2.putText(img3.copy(),"BOOTIFUL",(225,330),cv2. FONT_HERSHEY_SCRIPT_COMPLEX,1,(255,0,0),1)
img6=cv2.rectangle(img3.copy(),(415,300),(200,345),(0,0,255),8)
cv2_imshow(img6)

#Project/selfmade
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>

# %%
img5=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh=cv2.threshold(img5,120,255,cv2.THRESH_BINARY)
cv2_imshow(thresh)
#to add threshold value in the image
# Out:
# <PIL.Image.Image image mode=L size=612x408>

# %%
im6=cv2.Canny(img,100,200)
cv2_imshow(im6)
#to add canny edge detection
# Out:
# <PIL.Image.Image image mode=L size=612x408>

# %%
cv2.imwrite("igsk.jpg",img)
#to save the image
# Out:
# True
